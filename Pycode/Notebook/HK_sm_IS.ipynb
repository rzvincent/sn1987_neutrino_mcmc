# %%
from definition import Seesaw_Inverse

print(f"Seesaw_Inverse is set to: {Seesaw_Inverse}")

osc = False  # Set to True for oscillation, False for no oscillation 

if osc:
    import SignalRate_2d_osc as s2d   # with oscillation
else:
    import SignalRate_2d as s2d     # without oscillation

path_sample = r'./Data/samples_HK_osc.npy' if osc else r'./Data/samples_HK.npy'

import numpy as np
from scipy.optimize import minimize
import definition as df
from Simulation_Spectrum import time_limit

path_ret_osc = r'./Data/m_lambda_space_2d_osc.npy' 
path_ret = r'./Data/m_lambda_space_2d.npy'

precision = 64
E_range = (5, 50)
t_range = (0.01, time_limit('max'))

E_min, E_max = E_range
t_min, t_max = t_range

range_k = [t_range, E_range,  (-1, 1)]

def SR_HK(t, E_e, c, *args):

    R_c, T_c, tau_c, M_a, T_a, tau_a, m_phi, lambda_nu = args

    # N_K = 1.43e32 # for K-II

    N_K = 1.26e34 # for HK

    # eff_K = 0.932/np.sqrt(1+(34/(12-7*E_e+E_e**2))**2)        # This one is not well-fitted

    eff_K = 1

    ret = N_K * s2d.cs_at_c(c, s2d.E_nu(E_e, c)) * s2d.flux_2d(t, s2d.E_nu(E_e, c), R_c, T_c, tau_c, M_a, T_a, tau_a, m_phi, lambda_nu) * s2d.E_nu_at_E_e(E_e, c) * eff_K

    if osc: # To make the sample size comparable with the non-oscillation case
        k = 1994/1784   # calculated before
        ret = k * ret

    return ret


params = [0, 0, 0, 0, 0, 0, -4, -16]    # null hypothesis parameters for the flux function

if osc:
    print("Running with oscillation effects. Make sure to import SignalRate_2d_osc as s2d.")
else:
    print("Running without oscillation effects. Make sure to import SignalRate_2d as s2d.")
# Out:
# Seesaw_Inverse is set to: True
# Running without oscillation effects. Make sure to import SignalRate_2d as s2d.

# %%
# sample size calculation

def minimize_sr(vars):
    t, E = vars
    return - SR_HK(t, E, 0,*params)

ret = minimize(minimize_sr, x0=[0.1, 10], bounds=(t_range, E_range), method='L-BFGS-B')

print('f_max and coordinates', -ret.fun, ret.x)

f_max = -ret.fun
num_samples = df.gl3_integrate(SR_HK, range_k, precision, args=params)
print('simple size:', num_samples)
# Out:
# f_max and coordinates 37.26848213985868 [ 0.10134365 13.7664395 ]
# simple size: 1994.4748061587475

# %%
# sample simlulation

def sample_rejection(flux_func, E_range, t_range, f_max, num_samples, *args):
    samples = []
    
    while len(samples) < num_samples:
        # 1. Propose E and t uniformly within your bounds
        E_prop = np.random.uniform(E_range[0], E_range[1])
        t_prop = np.random.uniform(t_range[0], t_range[1])
        
        # 2. Draw a uniform height to test against the flux
        u = np.random.uniform(0, f_max)
        
        # 3. Accept if the test height is under the distribution surface
        if u < flux_func(t_prop, E_prop, 0, *args):
            samples.append((t_prop, E_prop))
            
    return np.array(samples)

t_samples, E_samples = sample_rejection(SR_HK, E_range, t_range, f_max, num_samples, *params).T

np.save(path_sample, np.array([t_samples, E_samples]).T)

# %%
import numpy as np
import definition as df


E_min, E_max = E_range
t_min, t_max = t_range

t_samples = np.load(path_sample)[:, 0]
E_samples = np.load(path_sample)[:, 1]

print('sample shape', t_samples.shape, E_samples.shape)

range_k = [t_range, E_range,  (-1, 1)]

def param_set(log_m, log_lambda):
    return [0, 0, 0, 0, 0, 0, log_m, log_lambda]

def log_likelihood(log_m, log_lambda):

    fun1_K = lambda x: SR_HK(t_samples, x, 0, *param_set(log_m, log_lambda))

    part1_K = df.gl3_integrate(SR_HK, range_k, precision, args=param_set(log_m, log_lambda))

    part2_K = df.gl_integrate(fun1_K, E_min, E_max, precision = 64)

    part3_K = 1e-4

    ret_K = -part1_K + np.sum(np.log(part3_K + part2_K))

    return ret_K

def chi_2(log_m, log_lambda):
    return -2 * log_likelihood(log_m, log_lambda)

# print('baseline:', chi_2(-4, -12))
print('this one must be positive, if not, check whether the right data is used')
print('assume:', chi_2(3, -7.8) - chi_2(-4, -16))

print('benchmark:', log_likelihood(-4, -16))
print('assume:', log_likelihood(2, -7.8))
# Out:
# sample shape (1996,) (1996,)
# this one must be positive, if not, check whether the right data is used
# assume: -7.839844329282641e-09
# benchmark: 8928.976820445423
# assume: 8928.976432327163

# %%
import numpy as np
from scipy.optimize import minimize, root_scalar

log_m_vals = np.concatenate((np.linspace(0, 2.3, 30), np.linspace(2.31, 4, 170)))
log_lambda_95CL = []

for log_m in log_m_vals:

    best_log_lambda = -10
    chi2_min = chi_2(-4, -16)
    # this is the benchmark of minimum chi_2

    upper_bracket = best_log_lambda + 7  # Adjust if you expect the limit to be higher than this.

    target_chi2 = chi2_min + 3.84
    
    def root_func(l_lambda):
        return chi_2(log_m, l_lambda) - target_chi2
        
    try:
        res_root = root_scalar(root_func, bracket=[best_log_lambda, upper_bracket], method='brentq')
        print('best_log_lambda', best_log_lambda, 'log_m:', log_m, 'log_lambda:', res_root.root)
        log_lambda_95CL.append(res_root.root)
        
    except ValueError:
        print('best_log_lambda', best_log_lambda)
        print(f"Failed to bracket root at log_m = {log_m}. Check the bracket range.")
        log_lambda_95CL.append(np.nan)


log_lambda_95CL = np.array(log_lambda_95CL)
print(log_lambda_95CL)

if osc:
    np.save(path_ret_osc, np.array([log_m_vals, log_lambda_95CL]).T)
else:
    np.save(path_ret, np.array([log_m_vals, log_lambda_95CL]).T)
# Out:
# best_log_lambda -10 log_m: 0.0 log_lambda: -5.517487763749337
# best_log_lambda -10 log_m: 0.0793103448275862 log_lambda: -5.518812415923808
# best_log_lambda -10 log_m: 0.1586206896551724 log_lambda: -5.521474353977351
# best_log_lambda -10 log_m: 0.2379310344827586 log_lambda: -5.52432513146324
# best_log_lambda -10 log_m: 0.3172413793103448 log_lambda: -5.528604379494794
# best_log_lambda -10 log_m: 0.396551724137931 log_lambda: -5.531859965831115
# best_log_lambda -10 log_m: 0.4758620689655172 log_lambda: -5.540581593268452
# best_log_lambda -10 log_m: 0.5551724137931033 log_lambda: -5.547933764420331
# best_log_lambda -10 log_m: 0.6344827586206896 log_lambda: -5.559471984365248
# best_log_lambda -10 log_m: 0.7137931034482758 log_lambda: -5.578461633243356
# best_log_lambda -10 log_m: 0.793103448275862 log_lambda: -5.602349361806374
# best_log_lambda -10 log_m: 0.8724137931034481 log_lambda: -5.630334261962379
# best_log_lambda -10 log_m: 0.9517241379310344 log_lambda: -5.673511065237217
# best_log_lambda -10 log_m: 1.0310344827586206 log_lambda: -5.717345360201732
# best_log_lambda -10 log_m: 1.1103448275862067 log_lambda: -5.765926074319439
# best_log_lambda -10 log_m: 1.189655172413793 log_lambda: -5.821406944269364
# best_log_lambda -10 log_m: 1.2689655172413792 log_lambda: -5.8711654646944735
# best_log_lambda -10 log_m: 1.3482758620689654 log_lambda: -5.944672868798319
# best_log_lambda -10 log_m: 1.4275862068965517 log_lambda: -6.002292542029662
# best_log_lambda -10 log_m: 1.5068965517241377 log_lambda: -6.0717398523117305
# best_log_lambda -10 log_m: 1.586206896551724 log_lambda: -6.129614267763583
# best_log_lambda -10 log_m: 1.6655172413793102 log_lambda: -6.200114875555379
# best_log_lambda -10 log_m: 1.7448275862068963 log_lambda: -6.2567379266823435
# best_log_lambda -10 log_m: 1.8241379310344825 log_lambda: -6.31246545390923
# best_log_lambda -10 log_m: 1.9034482758620688 log_lambda: -6.352031573587283
# best_log_lambda -10 log_m: 1.982758620689655 log_lambda: -6.376488070361168
# best_log_lambda -10 log_m: 2.0620689655172413 log_lambda: -6.379332199184657
# best_log_lambda -10 log_m: 2.1413793103448273 log_lambda: -6.359669810524767
# best_log_lambda -10 log_m: 2.2206896551724133 log_lambda: -6.304310601502203
# best_log_lambda -10 log_m: 2.3 log_lambda: -6.2066479837771
# best_log_lambda -10 log_m: 2.31 log_lambda: -6.191546192625292
# best_log_lambda -10 log_m: 2.32 log_lambda: -6.174417241678273
# best_log_lambda -10 log_m: 2.33 log_lambda: -6.158962299261066
# best_log_lambda -10 log_m: 2.34 log_lambda: -6.139651929278966
# best_log_lambda -10 log_m: 2.35 log_lambda: -6.121458124469893
# best_log_lambda -10 log_m: 2.36 log_lambda: -6.10093140164664
# best_log_lambda -10 log_m: 2.37 log_lambda: -6.0817239432725065
# best_log_lambda -10 log_m: 2.38 log_lambda: -6.059556136592933
# best_log_lambda -10 log_m: 2.39 log_lambda: -6.0373036256666825
# best_log_lambda -10 log_m: 2.4 log_lambda: -6.0144840428732955
# best_log_lambda -10 log_m: 2.41 log_lambda: -5.989738073800407
# best_log_lambda -10 log_m: 2.42 log_lambda: -5.96483153677792
# best_log_lambda -10 log_m: 2.43 log_lambda: -5.93807496671054
# best_log_lambda -10 log_m: 2.44 log_lambda: -5.911838365495598
# best_log_lambda -10 log_m: 2.45 log_lambda: -5.884607925057486
# best_log_lambda -10 log_m: 2.46 log_lambda: -5.853908481928214
# best_log_lambda -10 log_m: 2.47 log_lambda: -5.821623504995826
# best_log_lambda -10 log_m: 2.48 log_lambda: -5.790231858057305
# best_log_lambda -10 log_m: 2.49 log_lambda: -5.759808907634835
# best_log_lambda -10 log_m: 2.5 log_lambda: -5.72827298690873
# best_log_lambda -10 log_m: 2.5100000000000002 log_lambda: -5.6931700479165475
# best_log_lambda -10 log_m: 2.52 log_lambda: -5.65540871790593
# best_log_lambda -10 log_m: 2.5300000000000002 log_lambda: -5.615528996616023
# best_log_lambda -10 log_m: 2.54 log_lambda: -5.57559184403383
# best_log_lambda -10 log_m: 2.55 log_lambda: -5.534887706443956
# best_log_lambda -10 log_m: 2.56 log_lambda: -5.4930508014438235
# best_log_lambda -10 log_m: 2.5700000000000003 log_lambda: -5.450400136509861
# best_log_lambda -10 log_m: 2.58 log_lambda: -5.406636082486331
# best_log_lambda -10 log_m: 2.59 log_lambda: -5.3612684339757495
# best_log_lambda -10 log_m: 2.6 log_lambda: -5.314662188986085
# best_log_lambda -10 log_m: 2.61 log_lambda: -5.267048543672272
# best_log_lambda -10 log_m: 2.62 log_lambda: -5.217537091720026
# best_log_lambda -10 log_m: 2.63 log_lambda: -5.165898138876981
# best_log_lambda -10 log_m: 2.64 log_lambda: -5.113143998422182
# best_log_lambda -10 log_m: 2.65 log_lambda: -5.059403550236905
# best_log_lambda -10 log_m: 2.66 log_lambda: -5.005313787309184
# best_log_lambda -10 log_m: 2.67 log_lambda: -4.950409187939733
# best_log_lambda -10 log_m: 2.68 log_lambda: -4.89446683480353
# best_log_lambda -10 log_m: 2.69 log_lambda: -4.8394415907988515
# best_log_lambda -10 log_m: 2.7 log_lambda: -4.784042353004588
# best_log_lambda -10 log_m: 2.71 log_lambda: -4.7297825895107115
# best_log_lambda -10 log_m: 2.72 log_lambda: -4.6770597585139955
# best_log_lambda -10 log_m: 2.73 log_lambda: -4.625674249975392
# best_log_lambda -10 log_m: 2.74 log_lambda: -4.576851984410148
# best_log_lambda -10 log_m: 2.75 log_lambda: -4.530745554213627
# best_log_lambda -10 log_m: 2.7600000000000002 log_lambda: -4.487544475872141
# best_log_lambda -10 log_m: 2.77 log_lambda: -4.447457689263066
# best_log_lambda -10 log_m: 2.7800000000000002 log_lambda: -4.410505857413228
# best_log_lambda -10 log_m: 2.79 log_lambda: -4.376538475498067
# best_log_lambda -10 log_m: 2.8 log_lambda: -4.34518276317178
# best_log_lambda -10 log_m: 2.81 log_lambda: -4.316032503254485
# best_log_lambda -10 log_m: 2.8200000000000003 log_lambda: -4.2886650394655055
# best_log_lambda -10 log_m: 2.83 log_lambda: -4.262656999878618
# best_log_lambda -10 log_m: 2.84 log_lambda: -4.237662763871374
# best_log_lambda -10 log_m: 2.85 log_lambda: -4.213403454179462
# best_log_lambda -10 log_m: 2.8600000000000003 log_lambda: -4.18968231551139
# best_log_lambda -10 log_m: 2.87 log_lambda: -4.166378643884137
# best_log_lambda -10 log_m: 2.88 log_lambda: -4.143377990500582
# best_log_lambda -10 log_m: 2.89 log_lambda: -4.120562626056979
# best_log_lambda -10 log_m: 2.9 log_lambda: -4.097974407017641
# best_log_lambda -10 log_m: 2.91 log_lambda: -4.0756162178810005
# best_log_lambda -10 log_m: 2.92 log_lambda: -4.053384254454939
# best_log_lambda -10 log_m: 2.93 log_lambda: -4.031276530978585
# best_log_lambda -10 log_m: 2.94 log_lambda: -4.009293879748897
# best_log_lambda -10 log_m: 2.95 log_lambda: -3.9874276824235855
# best_log_lambda -10 log_m: 2.96 log_lambda: -3.9656693366154356
# best_log_lambda -10 log_m: 2.97 log_lambda: -3.9440109998510873
# best_log_lambda -10 log_m: 2.98 log_lambda: -3.922445593002373
# best_log_lambda -10 log_m: 2.99 log_lambda: -3.900966717431153
# best_log_lambda -10 log_m: 3.0 log_lambda: -3.8795685692363993
# best_log_lambda -10 log_m: 3.0100000000000002 log_lambda: -3.8582458640156063
# best_log_lambda -10 log_m: 3.02 log_lambda: -3.836993773089155
# best_log_lambda -10 log_m: 3.0300000000000002 log_lambda: -3.8158078697086086
# best_log_lambda -10 log_m: 3.04 log_lambda: -3.7946840835546047
# best_log_lambda -10 log_m: 3.05 log_lambda: -3.7736186619935332
# best_log_lambda -10 log_m: 3.06 log_lambda: -3.7526081368868938
# best_log_lambda -10 log_m: 3.0700000000000003 log_lambda: -3.7316492959629484
# best_log_lambda -10 log_m: 3.08 log_lambda: -3.7107391579730407
# best_log_lambda -10 log_m: 3.09 log_lambda: -3.6898749510082935
# best_log_lambda -10 log_m: 3.1 log_lambda: -3.6690540934743674
# best_log_lambda -10 log_m: 3.1100000000000003 log_lambda: -3.6482741773155722
# best_log_lambda -10 log_m: 3.12 log_lambda: -3.6275329531564413
# best_log_lambda -10 log_m: 3.13 log_lambda: -3.6068283170867317
# best_log_lambda -10 log_m: 3.14 log_lambda: -3.586158298861817
# best_log_lambda -10 log_m: 3.15 log_lambda: -3.565521051329385
# best_log_lambda -10 log_m: 3.16 log_lambda: -3.5449148409237226
# best_log_lambda -10 log_m: 3.17 log_lambda: -3.5243380390918118
# best_log_lambda -10 log_m: 3.18 log_lambda: -3.503789114540055
# best_log_lambda -10 log_m: 3.19 log_lambda: -3.4832666262001934
# best_log_lambda -10 log_m: 3.2 log_lambda: -3.462769216834808
# best_log_lambda -10 log_m: 3.21 log_lambda: -3.442295607207843
# best_log_lambda -10 log_m: 3.22 log_lambda: -3.421844590760402
# best_log_lambda -10 log_m: 3.23 log_lambda: -3.4014150287339247
# best_log_lambda -10 log_m: 3.24 log_lambda: -3.3810058457004533
# best_log_lambda -10 log_m: 3.25 log_lambda: -3.360616025450061
# best_log_lambda -10 log_m: 3.2600000000000002 log_lambda: -3.34024460720774
# best_log_lambda -10 log_m: 3.27 log_lambda: -3.319890682142247
# best_log_lambda -10 log_m: 3.2800000000000002 log_lambda: -3.2995533901412366
# best_log_lambda -10 log_m: 3.29 log_lambda: -3.2792319168281114
# best_log_lambda -10 log_m: 3.3 log_lambda: -3.2589254907975493
# best_log_lambda -10 log_m: 3.31 log_lambda: -3.2386333810499237
# best_log_lambda -10 log_m: 3.3200000000000003 log_lambda: -3.21835489460851
# best_log_lambda -10 log_m: 3.33 log_lambda: -3.1980893743024628
# best_log_lambda -10 log_m: 3.34 log_lambda: -3.177836196700641
# best_log_lambda -10 log_m: 3.35 log_lambda: -3.1575947701899376
# best_log_lambda -10 log_m: 3.3600000000000003 log_lambda: -3.1373645331735673
# best_log_lambda -10 log_m: 3.37 log_lambda: -3.11714495239553
# best_log_lambda -10 log_m: 3.38 log_lambda: -3.096935521368294
# best_log_lambda -10 log_m: 3.39 log_lambda: -3.0767357589024225
# best_log_lambda -10 log_m: 3.4000000000000004 log_lambda: -3.056545207729524
# best_log_lambda -10 log_m: 3.41 log_lambda: -3.036363433210855
# best_log_lambda -10 log_m: 3.42 log_lambda: -3.016190022122363
# best_log_lambda -10
# Failed to bracket root at log_m = 3.43. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.4400000000000004. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.45. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.46. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.4699999999999998. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.48. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.49. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.5. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.51. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.52. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.5300000000000002. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.54. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.55. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.56. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.5700000000000003. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.58. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.59. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.6. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.6100000000000003. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.62. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.63. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.64. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.6500000000000004. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.66. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.67. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.68. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.6900000000000004. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.7. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.71. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.7199999999999998. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.73. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.74. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.75. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.76. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.77. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.7800000000000002. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.79. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.8. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.81. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.8200000000000003. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.83. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.84. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.85. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.8600000000000003. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.87. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.88. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.89. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.9000000000000004. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.91. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.92. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.93. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.9400000000000004. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.95. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.96. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.97. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.98. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 3.99. Check the bracket range.
# best_log_lambda -10
# Failed to bracket root at log_m = 4.0. Check the bracket range.
# [-5.51748776 -5.51881242 -5.52147435 -5.52432513 -5.52860438 -5.53185997
#  -5.54058159 -5.54793376 -5.55947198 -5.57846163 -5.60234936 -5.63033426
#  -5.67351107 -5.71734536 -5.76592607 -5.82140694 -5.87116546 -5.94467287
#  -6.00229254 -6.07173985 -6.12961427 -6.20011488 -6.25673793 -6.31246545
#  -6.35203157 -6.37648807 -6.3793322  -6.35966981 -6.3043106  -6.20664798
#  -6.19154619 -6.17441724 -6.1589623  -6.13965193 -6.12145812 -6.1009314
#  -6.08172394 -6.05955614 -6.03730363 -6.01448404 -5.98973807 -5.96483154
#  -5.93807497 -5.91183837 -5.88460793 -5.85390848 -5.8216235  -5.79023186
#  -5.75980891 -5.72827299 -5.69317005 -5.65540872 -5.615529   -5.57559184
#  -5.53488771 -5.4930508  -5.45040014 -5.40663608 -5.36126843 -5.31466219
#  -5.26704854 -5.21753709 -5.16589814 -5.113144   -5.05940355 -5.00531379
#  -4.95040919 -4.89446683 -4.83944159 -4.78404235 -4.72978259 -4.67705976
#  -4.62567425 -4.57685198 -4.53074555 -4.48754448 -4.44745769 -4.41050586
#  -4.37653848 -4.34518276 -4.3160325  -4.28866504 -4.262657   -4.23766276
#  -4.21340345 -4.18968232 -4.16637864 -4.14337799 -4.12056263 -4.09797441
#  -4.07561622 -4.05338425 -4.03127653 -4.00929388 -3.98742768 -3.96566934
#  -3.944011   -3.92244559 -3.90096672 -3.87956857 -3.85824586 -3.83699377
#  -3.81580787 -3.79468408 -3.77361866 -3.75260814 -3.7316493  -3.71073916
#  -3.68987495 -3.66905409 -3.64827418 -3.62753295 -3.60682832 -3.5861583
#  -3.56552105 -3.54491484 -3.52433804 -3.50378911 -3.48326663 -3.46276922
#  -3.44229561 -3.42184459 -3.40141503 -3.38100585 -3.36061603 -3.34024461
#  -3.31989068 -3.29955339 -3.27923192 -3.25892549 -3.23863338 -3.21835489
#  -3.19808937 -3.1778362  -3.15759477 -3.13736453 -3.11714495 -3.09693552
#  -3.07673576 -3.05654521 -3.03636343 -3.01619002         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan]

# %%
# only for plots

log_m_vals, log_lambda_95CL = np.load(path_ret).T
log_m_vals_osc, log_lambda_95CL_osc = np.load(path_ret_osc).T
log_m_vals_tpi, log_lambda_95CL_tpi = np.load(r'./Data/m_lambda_space_2d_osc_TPI.npy' ).T

# %matplotlib inline
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

ax.plot(10**log_m_vals, 10**log_lambda_95CL, label=r'$2\sigma$ Flavor Blind')
ax.plot(10**log_m_vals_osc, 10**log_lambda_95CL_osc, label=r'$2\sigma$ w.Oscillation (Inverse)', linestyle='--')
ax.plot(10**log_m_vals_tpi, 10**log_lambda_95CL_tpi, label=r'$2\sigma$ w.Oscillation (Type I)', linestyle=':')

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$m_{\phi}$ (eV)')
ax.set_ylabel(r'$\lambda_{\phi\nu}$')
ax.set_xlim(1, 1e3)
ax.set_ylim(1e-11, 4e-5)
ax.legend()

fig

# %%
# obsolete, but still useful for testing the signal rate function

import numpy as np
import matplotlib.pyplot as plt
import definition as df
import SignalRate_2d as s2d
from Simulation_Spectrum import time_limit

t_range = (0.01, time_limit('max'))


t_samples = np.load(r'F:/Neutrino_SI/Data/samples_HK.npy')[:, 0]
E_samples = np.load(r'F:/Neutrino_SI/Data/samples_HK.npy')[:, 1]

def SR_HK(t, E_e, c, *args):

    R_c, T_c, tau_c, M_a, T_a, tau_a, m_phi, lambda_nu = args

    # N_K = 1.43e32 # for K-II

    N_K = 1.26e34 # for HK

    # eff_K = 0.932/np.sqrt(1+(34/(12-7*E_e+E_e**2))**2)        # This one is not well-fitted

    eff_K = 1

    ret = N_K * s2d.cs_at_c(c, s2d.E_nu(E_e, c)) * s2d.flux_2d(t, s2d.E_nu(E_e, c), R_c, T_c, tau_c, M_a, T_a, tau_a, m_phi, lambda_nu) * s2d.E_nu_at_E_e(E_e, c) * eff_K

    return ret

params_1 = [0, 0, 0, 0, 0, 0, -4, -12]
params_2 = [0, 0, 0, 0, 0, 0, 1.2244897959183674, -6.0228186190835595]
ranges: list = [(5, 50),  (-1, 1)]
bin_num = 50

integ_1 = lambda E, c, t: SR_HK(t, E, c, *params_1)
integ_2 = lambda E, c, t: SR_HK(t, E, c, *params_2)

t_space = np.linspace(t_range[0], t_range[1], 100)
y_1 = df.gl2_integrate_vec(integ_1, ranges, t_space)*t_range[1]/bin_num
# y_2 = df.gl2_integrate_vec(integ_2, ranges, t_space)*t_range[1]/bin_num

fig, ax = plt.subplots()
ax.hist(t_samples, bins=bin_num, alpha=0.5, label='Time Samples', color='blue', histtype = 'step')
ax.plot(t_space, y_1, label='SR at Samples', color = 'red', linestyle='--')
# ax.plot(t_space, y_2, label='SR at 95% CL', color = 'green', linestyle='--')
ax.set_xlabel('Time (s)')
ax.set_ylabel('Signal Rate')
plt.legend()

fig
